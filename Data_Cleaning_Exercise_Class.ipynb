# %% [markdown]
# # Data Cleaning in Python — Exercise
#
# **Course:** Intro to Data Mining
# **Dataset:** Heart Failure Prediction dataset (loaded from a public URL — no file downloads needed!)
#
# ---

# %% [markdown]
# # YOUR TURN: Practice Exercise
#
# Now apply the same data cleaning pipeline from the Titanic exercise to a **new dataset**: the **Heart Failure Prediction** dataset.
#
# This dataset combines 5 heart disease databases (918 patients total) and contains medical information about patients and whether or not they have heart disease. It has **text columns that need encoding**, potential outliers, and some tricky data quality issues — perfect for practicing everything we just learned.
#
# **Your tasks** (follow the same steps from above):
#
# 1. Load the data and take a first look
# 2. Understand the data types and structure
# 3. Get descriptive statistics
# 4. Check for duplicates
# 5. Handle missing values (decide: drop column, drop row, or impute?)
# 6. Encode any categorical (`object`) columns
# 7. Detect and handle outliers
# 8. Scale the numerical features
#
# The starter code below loads the dataset for you. The rest is up to you!
#
# > **Hints:** Pay close attention to `.describe()` — not all missing values show up as NaN! Also, this dataset was made by combining multiple hospital databases, so check for duplicates.

# %% [markdown]
# ### About the Heart Failure Prediction Dataset
#
# | Column | Description | Type |
# |--------|-------------|------|
# | Age | Age in years | Numerical |
# | Sex | M = Male, F = Female | Categorical |
# | ChestPainType | TA = Typical Angina, ATA = Atypical Angina, NAP = Non-Anginal Pain, ASY = Asymptomatic | Categorical |
# | RestingBP | Resting blood pressure (mm Hg) | Numerical |
# | Cholesterol | Serum cholesterol (mg/dl) | Numerical |
# | FastingBS | Fasting blood sugar > 120 mg/dl (1 = true, 0 = false) | Numerical |
# | RestingECG | Normal, ST = ST-T wave abnormality, LVH = left ventricular hypertrophy | Categorical |
# | MaxHR | Maximum heart rate achieved | Numerical |
# | ExerciseAngina | Y = Yes, N = No | Categorical |
# | Oldpeak | ST depression induced by exercise | Numerical |
# | ST_Slope | Up = upsloping, Flat = flat, Down = downsloping | Categorical |
# | HeartDisease | 1 = heart disease, 0 = no heart disease (TARGET) | Numerical |

# %% [markdown]
# ### Step 1: Load the data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# The Heart Failure Prediction dataset — loaded from a public GitHub URL
# (Originally from Kaggle, combining 5 UCI heart disease databases)
url = 'https://raw.githubusercontent.com/xpy-10/DataSet/main/heart.csv'

heart = pd.read_csv(url)

print(f'Dataset shape: {heart.shape[0]} rows x {heart.shape[1]} columns')
heart.head()

# %% [markdown]
# ### Step 2: Check data types and structure
#
# Use `.info()` to see the data types and count non-null values.

# %%
heart.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    float64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    float64
#  4   Cholesterol     918 non-null    float64
#  5   FastingBS       918 non-null    float64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    float64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 86.2+ KB

# %% [markdown]
# ### Step 3: Descriptive statistics
#
# Use `.describe()`. Look for anything surprising in the min, max, or mean values.

# %%
print("Shape:", heart.shape)
print("\nInfo:")
print(heart.info())

print("\nDescribe (numeric):")
display(heart.describe())

print("\nMissing values per column:")
print(heart.isna().sum())
# Out:
# Shape: (918, 12)
#
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 918 entries, 0 to 917
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Age             918 non-null    float64
#  1   Sex             918 non-null    object
#  2   ChestPainType   918 non-null    object
#  3   RestingBP       918 non-null    float64
#  4   Cholesterol     918 non-null    float64
#  5   FastingBS       918 non-null    float64
#  6   RestingECG      918 non-null    object
#  7   MaxHR           918 non-null    float64
#  8   ExerciseAngina  918 non-null    object
#  9   Oldpeak         918 non-null    float64
#  10  ST_Slope        918 non-null    object
#  11  HeartDisease    918 non-null    int64
# dtypes: float64(6), int64(1), object(5)
# memory usage: 86.2+ KB
# None
#
# Describe (numeric):
#               Age   RestingBP  Cholesterol   FastingBS       MaxHR  \
# count  918.000000  918.000000   918.000000  918.000000  918.000000
# mean     0.520630    0.526566     0.456960    0.233115    0.520729
# std      0.192502    0.212416     0.255793    0.423046    0.187000
# min      0.000000    0.000000     0.000000    0.000000    0.000000
# 25%      0.387755    0.375000     0.375000    0.000000    0.397059
# 50%      0.530612    0.500000     0.507667    0.000000    0.529412
# 75%      0.653061    0.625000     0.625000    0.000000    0.661765
# max      1.000000    1.000000     1.000000    1.000000    1.000000
#
#           Oldpeak  HeartDisease
# count  918.000000    918.000000
# mean     0.396291      0.553377
# std      0.121201      0.497414
# min      0.000000      0.000000
# 25%      0.295455      0.000000
# 50%      0.363636      1.000000
# 75%      0.465909      1.000000
# max      1.000000      1.000000
# Missing values per column:
# Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %% [markdown]
# ### Step 4: Check for duplicates
#
# How many duplicate rows are there? If any, remove them.

# %%
print("Duplicates before:", heart.duplicated().sum())
heart = heart.drop_duplicates().copy()
print("Duplicates after:", heart.duplicated().sum())
# Out:
# Duplicates before: 0
# Duplicates after: 0

# %% [markdown]
# ### Step 5: Handle missing values
#
# Check the percentage of missing values per column. Then decide what to do:
# - Drop columns that are mostly missing
# - Drop rows if very few are missing
# - Impute (fill) with mean or median if a moderate amount is missing

# %%
num_cols = heart.select_dtypes(include=[np.number]).columns.tolist()

mins = heart[num_cols].min()
maxs = heart[num_cols].max()

scaled_like = ((mins >= 0) & (maxs <= 1)).mean()  # fraction of numeric cols in [0,1]

print("Fraction of numeric columns within [0,1]:", scaled_like)
print("\nMin values:\n", mins)
print("\nMax values:\n", maxs)

if scaled_like > 0.9:
    print("\n✅ Dataset appears already MinMax-scaled. We will NOT treat 0 as invalid and we will NOT scale again.")
else:
    print("\n⚠️ Dataset does NOT appear fully scaled. (Different cleaning rules may be needed.)")
# Out:
# Fraction of numeric columns within [0,1]: 1.0
#
# Min values:
#  Age             0.0
# RestingBP       0.0
# Cholesterol     0.0
# FastingBS       0.0
# MaxHR           0.0
# Oldpeak         0.0
# HeartDisease    0.0
# dtype: float64
#
# Max values:
#  Age             1.0
# RestingBP       1.0
# Cholesterol     1.0
# FastingBS       1.0
# MaxHR           1.0
# Oldpeak         1.0
# HeartDisease    1.0
# dtype: float64
#
# ✅ Dataset appears already MinMax-scaled. We will NOT treat 0 as invalid and we will NOT scale again.

# %% [markdown]
# ### Step 6: Encode categorical variables
#
# Check if any columns are `object` type. If so, decide whether to use label encoding or one-hot encoding.
#
# Hint: Look at `.info()` output — how many unique values does each `object` column have?

# %%
num_cols = heart.select_dtypes(include=[np.number]).columns
cat_cols = heart.select_dtypes(exclude=[np.number]).columns

for col in num_cols:
    if heart[col].isna().sum() > 0:
        heart[col] = heart[col].fillna(heart[col].median())

for col in cat_cols:
    if heart[col].isna().sum() > 0:
        heart[col] = heart[col].fillna(heart[col].mode()[0])

print("Missing values after filling:\n", heart.isna().sum())
# Out:
# Missing values after filling:
#  Age               0
# Sex               0
# ChestPainType     0
# RestingBP         0
# Cholesterol       0
# FastingBS         0
# RestingECG        0
# MaxHR             0
# ExerciseAngina    0
# Oldpeak           0
# ST_Slope          0
# HeartDisease      0
# dtype: int64

# %%
# Step 6: Encode categorical variables

obj_cols = heart.select_dtypes(include='object').columns

for col in obj_cols:
    if heart[col].nunique() == 2:
        # Map binary categories
        unique_vals = heart[col].unique()
        heart[col] = heart[col].map({unique_vals[0]: 0, unique_vals[1]: 1})
    else:
        # One-hot encode
        heart = pd.get_dummies(heart, columns=[col], drop_first=True)

print("Encoding complete.")
# Out:
# Encoding complete.

# %% [markdown]
# ### Step 7: Detect and handle outliers
#
# Pick 2-3 numerical columns (e.g., `trestbps`, `chol`, `thalach`). Create box plots and use the IQR method.
#
# Remember: think about whether outliers are real data or errors before removing them!

# %%
# Function to detect outliers using IQR
def detect_outliers_iqr(df, col):
    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)
    IQR = Q3 - Q1
    lower = Q1 - 1.5 * IQR
    upper = Q3 + 1.5 * IQR
    outlier_mask = (df[col] < lower) | (df[col] > upper)
    return outlier_mask, lower, upper

# Pick 3 numerical columns
cols_to_check = ['RestingBP', 'Cholesterol', 'MaxHR']

print("Checking columns:", cols_to_check)

for col in cols_to_check:

    # Create boxplot BEFORE handling
    plt.figure()
    plt.boxplot(heart[col].dropna())
    plt.title(f"Boxplot BEFORE outlier handling: {col}")
    plt.ylabel(col)
    plt.show()

    # Detect outliers
    outlier_mask, lower, upper = detect_outliers_iqr(heart, col)
    print(f"{col}: {outlier_mask.sum()} outliers detected | lower={lower:.3f}, upper={upper:.3f}")

    # Since data is scaled and medical values may be valid,
    # we clip extreme values instead of deleting rows
    heart[col] = heart[col].clip(lower, upper)

    # Create boxplot AFTER handling
    plt.figure()
    plt.boxplot(heart[col].dropna())
    plt.title(f"Boxplot AFTER outlier handling: {col}")
    plt.ylabel(col)
    plt.show()
# Out:
# Checking columns: ['RestingBP', 'Cholesterol', 'MaxHR']
# RestingBP: 0 outliers detected | lower=0.000, upper=1.000
# Cholesterol: 0 outliers detected | lower=0.000, upper=1.000
# MaxHR: 2 outliers detected | lower=0.000, upper=1.059

# %% [markdown]
# ### Step 8: Scale the numerical features
#
# Apply Min-Max scaling to the numerical columns (not the target column).

# %%
from sklearn.preprocessing import MinMaxScaler
import numpy as np

# Identify numeric columns
num_cols = heart.select_dtypes(include=[np.number]).columns.tolist()

# Remove target column
if "HeartDisease" in num_cols:
    num_cols.remove("HeartDisease")

# Check if already scaled
mins = heart[num_cols].min()
maxs = heart[num_cols].max()

if (mins.min() >= 0) and (maxs.max() <= 1):
    print("Dataset already appears MinMax-scaled. Skipping scaling step.")
else:
    scaler = MinMaxScaler()
    heart[num_cols] = scaler.fit_transform(heart[num_cols])
    print("Scaling applied.")

heart.head()
# Out:
# Dataset already appears MinMax-scaled. Skipping scaling step.
#         Age  Sex  RestingBP  Cholesterol  FastingBS     MaxHR  ExerciseAngina  \
# 0  0.244898    0      0.625     0.683667        0.0  0.779412               0
# 1  0.428571    1      0.875     0.393000        0.0  0.661765               0
# 2  0.183673    0      0.500     0.667667        0.0  0.235294               0
# 3  0.408163    1      0.600     0.483667        0.0  0.308824               1
# 4  0.530612    0      0.750     0.433000        0.0  0.411765               0
#
#     Oldpeak  HeartDisease  ChestPainType_ATA  ChestPainType_NAP  \
# 0  0.295455             0               True              False
# 1  0.409091             1              False               True
# 2  0.295455             0               True              False
# 3  0.465909             1              False              False
# 4  0.295455             0              False               True
#
#    ChestPainType_TA  RestingECG_Normal  RestingECG_ST  ST_Slope_Flat  \
# 0             False               True          False          False
# 1             False               True          False           True
# 2             False              False           True          False
# 3             False               True          False           True
# 4             False               True          False          False
#
#    ST_Slope_Up
# 0         True
# 1        False
# 2         True
# 3        False
# 4         True

# %% [markdown]
# ### Reflection Questions
#
# After completing the exercise, answer these questions (add a text cell or answer here):
#
# 1. How did the Heart Disease dataset compare to the Titanic dataset in terms of data quality?
#
# A: The Heart Disease dataset was generally cleaner than the Titanic dataset - as it had fewer missing values and less data entry issues. For The Titanic dataset we had to check more extensively for data input errors (many missing values with age and cabin), whereas the Heart dataset only really required a check for duplicates, in which we had none.
#
# 2. Which missing value strategy did you use, and why?
#
# A: After checking for missed values, I noticed we had no missing cells. As a result, no imputation was needed.
#
# 3. Did you find any outliers? Did you remove them? Why or why not?
#
# A: Yes, I detected outliers using the IQR method and graphed them with boxplots. As the dataset was already handily MinMax scaled, I chose to only clip the extreme values rather than delete them entirely. This was initally confusing as some of the values for cholesterol and HR read as 0, which I initially interpreted as medically impossible. After noticing it was already scaled after running some checks, clipping seemed the most applicable as I didnt want to unnecessarily reduce the size of the dataset.
#
# 4. If you were building a model to predict heart disease, which columns do you think would be most important?
#
#
# A: Features such as MaxHR, RestingBP, Cholesterol, and Oldpeak would be important predictors. These variables are directly related to cardiovascular health and are commonly associated with heart disease risk. Additionally, categorical variables like ST_Slope and ChestPainType may also be strong predictors after encoding.

# %% [markdown]
# ---
# *Great work! You now have hands-on experience with a complete data cleaning pipeline.* Dr. Thompson
